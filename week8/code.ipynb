# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
fu = pd.read_csv('fu.csv', index_col=0)
fu
# Out:
#             Total trading     Deposit         Buy  Trading frequency  \
# identifier
# 1                       3   10.320000    9.940000          55.394352
# 2                      17   23.840000    1.969231        3432.536691
# 3                      11   16.135000    6.416667         965.519824
# 4                      10   17.185000    6.456000        2689.766296
# 5                       8   13.962500   15.248000        2508.149028
# ...                   ...         ...         ...                ...
# 2694                   19    4.820000    2.112000          31.598958
# 2695                   20   14.575000    2.235882          10.696481
# 2696                   48  986.048333  150.157805          11.224264
# 2698                    9  147.555000  109.808000          18.262014
# 2700                   15   32.120000    7.966667           5.475213
#
#             Account setup time  Churn percentage  Session length  cluster
# identifier
# ...

# %%
# Less active traders
cluster_0 = fu[fu['cluster'] == 0]
c0_id = cluster_0.index.tolist()
print("num: ",len(c0_id))
c0_id
# Out:
# num:  362
# [2,
#  3,
#  4,
#  5,
#  28,
#  34,
#  42,
#  44,
#  57,
#  65,
#  70,
#  74,
#  76,
#  82,
#  83,
#  92,
#  103,
#  125,
#  131,
#  157,
#  158,
#  160,
#  167,
#  174,
#  180,
#  192,
#  196,
#  198,
#  204,
#  206,
#  208,
#  219,
#  221,
#  223,
#  224,
#  225,
#  226,
#  227,
#  239,
#  245,
#  262,
#  265,
#  266,
#  267,
#  268,
#  276,
#  287,
#  289,
#  294,
#  297,
#  301,
#  318,
#  320,
#  331,
#  346,
#  364,
#  367,
#  376,
#  392,
#  401,
#  404,
#  410,
#  413,
#  433,
#  434,
#  442,
#  449,
#  456,
#  457,
#  458,
#  460,
#  461,
#  465,
#  467,
#  468,
#  469,
#  471,
#  472,
#  486,
#  504,
#  510,
#  511,
#  516,
#  519,
#  531,
#  532,
#  555,
#  556,
#  558,
#  561,
#  568,
#  569,
#  572,
#  574,
#  580,
#  586,
#  596,
#  604,
#  609,
#  610,
#  611,
#  614,
#  616,
#  620,
#  622,
#  634,
#  639,
#  641,
#  644,
#  653,
#  657,
#  658,
#  661,
#  667,
#  670,
#  678,
#  684,
#  688,
#  695,
#  700,
#  701,
#  706,
#  708,
#  709,
#  710,
#  719,
# ...

# %%
# Stable traders

cluster_1 = fu[fu['cluster'] == 1]
c1_id = cluster_1.index.tolist()
print("num: ",len(c1_id))
c1_id
# Out:
# num:  717
# [1,
#  7,
#  11,
#  23,
#  27,
#  98,
#  118,
#  122,
#  152,
#  175,
#  176,
#  203,
#  220,
#  234,
#  241,
#  257,
#  264,
#  270,
#  275,
#  280,
#  282,
#  283,
#  284,
#  288,
#  296,
#  303,
#  336,
#  340,
#  343,
#  348,
#  350,
#  352,
#  354,
#  370,
#  372,
#  377,
#  382,
#  403,
#  419,
#  425,
#  435,
#  446,
#  452,
#  464,
#  470,
#  485,
#  489,
#  498,
#  503,
#  525,
#  526,
#  527,
#  540,
#  541,
#  542,
#  545,
#  560,
#  566,
#  577,
#  583,
#  593,
#  601,
#  617,
#  630,
#  637,
#  640,
#  645,
#  655,
#  674,
#  680,
#  681,
#  682,
#  687,
#  690,
#  694,
#  699,
#  703,
#  716,
#  734,
#  735,
#  738,
#  747,
#  748,
#  754,
#  764,
#  786,
#  789,
#  800,
#  803,
#  808,
#  814,
#  817,
#  843,
#  861,
#  862,
#  864,
#  873,
#  875,
#  902,
#  913,
#  914,
#  916,
#  917,
#  932,
#  941,
#  957,
#  968,
#  969,
#  973,
#  974,
#  986,
#  998,
#  1008,
#  1012,
#  1014,
#  1027,
#  1037,
#  1042,
#  1058,
#  1061,
#  1062,
#  1063,
#  1065,
# ...

# %%
# Dormant traders

cluster_2 = fu[fu['cluster'] == 2]
c2_id = cluster_2.index.tolist()
print("num: ",len(c2_id))
c2_id
# Out:
# num:  468
# [13,
#  16,
#  18,
#  25,
#  26,
#  29,
#  30,
#  36,
#  40,
#  41,
#  47,
#  49,
#  50,
#  51,
#  55,
#  56,
#  62,
#  69,
#  71,
#  78,
#  81,
#  86,
#  93,
#  97,
#  107,
#  108,
#  111,
#  114,
#  116,
#  119,
#  124,
#  127,
#  129,
#  133,
#  134,
#  136,
#  137,
#  138,
#  140,
#  142,
#  143,
#  146,
#  148,
#  150,
#  163,
#  170,
#  172,
#  173,
#  178,
#  184,
#  185,
#  186,
#  193,
#  194,
#  197,
#  199,
#  202,
#  210,
#  213,
#  215,
#  218,
#  229,
#  232,
#  236,
#  244,
#  250,
#  254,
#  263,
#  272,
#  300,
#  304,
#  307,
#  308,
#  309,
#  312,
#  313,
#  316,
#  322,
#  326,
#  332,
#  338,
#  342,
#  349,
#  353,
#  355,
#  357,
#  358,
#  363,
#  365,
#  371,
#  380,
#  384,
#  385,
#  390,
#  391,
#  393,
#  394,
#  395,
#  396,
#  406,
#  416,
#  418,
#  423,
#  432,
#  436,
#  438,
#  439,
#  444,
#  447,
#  463,
#  473,
#  474,
#  475,
#  477,
#  490,
#  492,
#  496,
#  501,
#  506,
#  509,
#  520,
#  521,
#  522,
#  524,
#  528,
#  529,
# ...

# %%
# High value traders

cluster_3 = fu[fu['cluster'] == 3]
c3_id = cluster_3.index.tolist()
print("num: ",len(c3_id))
c3_id
# Out:
# num:  762
# [8,
#  10,
#  12,
#  15,
#  19,
#  20,
#  21,
#  31,
#  33,
#  35,
#  39,
#  43,
#  45,
#  58,
#  60,
#  61,
#  64,
#  66,
#  68,
#  73,
#  75,
#  85,
#  87,
#  88,
#  90,
#  91,
#  94,
#  95,
#  96,
#  100,
#  101,
#  102,
#  109,
#  110,
#  112,
#  113,
#  117,
#  120,
#  121,
#  123,
#  126,
#  130,
#  132,
#  135,
#  139,
#  141,
#  144,
#  145,
#  147,
#  149,
#  153,
#  154,
#  155,
#  162,
#  165,
#  168,
#  169,
#  171,
#  177,
#  179,
#  181,
#  182,
#  187,
#  188,
#  189,
#  190,
#  191,
#  195,
#  200,
#  201,
#  209,
#  211,
#  214,
#  216,
#  217,
#  228,
#  230,
#  233,
#  235,
#  237,
#  238,
#  240,
#  242,
#  247,
#  248,
#  249,
#  251,
#  252,
#  258,
#  259,
#  261,
#  269,
#  271,
#  273,
#  278,
#  281,
#  285,
#  286,
#  290,
#  292,
#  295,
#  298,
#  299,
#  302,
#  305,
#  306,
#  311,
#  314,
#  315,
#  319,
#  323,
#  324,
#  325,
#  327,
#  328,
#  329,
#  333,
#  334,
#  335,
#  339,
#  341,
#  344,
#  347,
#  356,
#  359,
#  362,
#  366,
# ...

# %%
data = pd.read_csv('Weekly_data.csv', index_col=0)
data['Week Number'] = data['Week Number'].str.replace('Week ', '').astype(int)
data
# Out:
#         Identifier  Week Number  Date Start    Date End source_of_wealth  \
# 0                1            1  2021/12/22  2021/12/28              NaN
# 1                1            2  2021/12/29    2022/1/4              NaN
# 2                1            3    2022/1/5   2022/1/11              NaN
# 3                1            4   2022/1/12   2022/1/18              NaN
# 4                1            5   2022/1/19   2022/1/25              NaN
# ...            ...          ...         ...         ...              ...
# 111547        2696           87   2023/8/16   2023/8/22          Savings
# 111548        2697           87   2023/8/16   2023/8/22          Savings
# 111549        2698           87   2023/8/16   2023/8/22     Your parents
# 111550        2699           87   2023/8/16   2023/8/22           Profit
# 111551        2700           87   2023/8/16   2023/8/22          Savings
#
#        employment_status  buy_values_7days  buy_number_7days  \
# ...

# %%
data.columns
# Out:
# Index(['Identifier', 'Week Number', 'Date Start', 'Date End',
#        'source_of_wealth', 'employment_status', 'buy_values_7days',
#        'buy_number_7days', 'buy_values_14days', 'buy_number_14days',
#        'sell_values_7days', 'sell_number_7days', 'sell_values_14days',
#        'sell_number_14days', 'net inflow 7days', 'net inflow 14days',
#        'Time since last trade', 'withdraw value 7days', 'withdraw times 7days',
#        'withdraw value 14days', 'withdraw times 14days', 'deposit value 7days',
#        'deposit times 7days', 'deposit value 14days', 'deposit times 14days',
#        'churn percentage', 'markert situation', 'Event(Withdraw) Count',
#        'Event(Stock) Count', 'Screen(Stock) Count', 'session length 7days',
#        'session length 14days', 'total events 7 days', 'total events 14days',
#        'buy value change', 'sell value change', 'buy number change',
#        'sell number change', 'deposit change', 'session time change',
# ...

# %% [markdown]
# 'buy_values_7days'
#
# 'buy_number_7days'
#
# 'buy_values_14days'
#
# 'buy_number_14days'
#
# 'sell_values_7days'
#
# 'sell_number_7days'
#
# 'sell_values_14days'
#
# 'sell_number_14days'
#
# 'session length 7days'
#
# 'session length 14days'
#
# 'total events 7 days'
#
# 'total events 14days'

# %% [markdown]
# ---
# ### High value traders
# ---

# %%
# High value traders
df_High_value_traders = data[data['Identifier'].isin(c3_id)]
df_High_value_traders
# Out:
#         Identifier  Week Number Date Start   Date End source_of_wealth  \
# 559              8           15  2022/3/30   2022/4/5          Savings
# 560              8           16   2022/4/6  2022/4/12          Savings
# 561              8           17  2022/4/13  2022/4/19          Savings
# 562              8           18  2022/4/20  2022/4/26          Savings
# 563              8           19  2022/4/27   2022/5/3          Savings
# ...            ...          ...        ...        ...              ...
# 111453        2649           87  2023/8/16  2023/8/22          Savings
# 111484        2660           85   2023/8/2   2023/8/8          Savings
# 111485        2660           86   2023/8/9  2023/8/15          Savings
# 111486        2660           87  2023/8/16  2023/8/22          Savings
# 111547        2696           87  2023/8/16  2023/8/22          Savings
#
#        employment_status  buy_values_7days  buy_number_7days  \
# ...

# %%
df_High_value_traders_Weekly = df_High_value_traders.groupby('Week Number').mean()
df_High_value_traders_Weekly = df_High_value_traders_Weekly.drop("Identifier", axis=1)
df_High_value_traders_Weekly = df_High_value_traders_Weekly.reset_index()
df_High_value_traders_Weekly
# Out:
# C:\Users\mrbri\AppData\Local\Temp\ipykernel_27616\4016993183.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_High_value_traders_Weekly = df_High_value_traders.groupby('Week Number').mean()
#     Week Number  buy_values_7days  buy_number_7days  buy_values_14days  \
# 0            15        485.584081          1.888889         485.584081
# 1            16        195.934393          2.658537         409.117648
# 2            17        425.918125          3.527273         571.978309
# 3            18       1037.683819          3.225806        1415.514414
# 4            19        675.031833          4.416667        1568.592899
# ..          ...               ...               ...                ...
# 68           83       1685.811100          2.303311        3616.842154
# ...

# %% [markdown]
# ---
# ### Stable traders
# ---

# %%
# Stable traders
df_Stable_traders = data[data['Identifier'].isin(c1_id)]
df_Stable_traders
# Out:
#         Identifier  Week Number  Date Start    Date End source_of_wealth  \
# 0                1            1  2021/12/22  2021/12/28              NaN
# 1                1            2  2021/12/29    2022/1/4              NaN
# 2                1            3    2022/1/5   2022/1/11              NaN
# 3                1            4   2022/1/12   2022/1/18              NaN
# 4                1            5   2022/1/19   2022/1/25              NaN
# ...            ...          ...         ...         ...              ...
# 111544        2693           87   2023/8/16   2023/8/22          Savings
# 111545        2694           87   2023/8/16   2023/8/22           Salary
# 111546        2695           87   2023/8/16   2023/8/22          Savings
# 111549        2698           87   2023/8/16   2023/8/22     Your parents
# 111551        2700           87   2023/8/16   2023/8/22          Savings
#
#        employment_status  buy_values_7days  buy_number_7days  \
# ...

# %%
df_Stable_traders_Weekly = df_Stable_traders.groupby('Week Number').mean()
df_Stable_traders_Weekly = df_Stable_traders_Weekly.drop("Identifier", axis=1)
df_Stable_traders_Weekly = df_Stable_traders_Weekly.reset_index()
df_Stable_traders_Weekly
# Out:
# C:\Users\mrbri\AppData\Local\Temp\ipykernel_27616\3316972918.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_Stable_traders_Weekly = df_Stable_traders.groupby('Week Number').mean()
#     Week Number  buy_values_7days  buy_number_7days  buy_values_14days  \
# 0             1         10.000000          1.000000          10.000000
# 1             2          9.880000          1.000000          19.880000
# 2             3          0.000000          0.000000           9.880000
# 3             4          0.000000          0.000000           0.000000
# 4             5          0.000000          0.000000           0.000000
# ..          ...               ...               ...                ...
# 82           83          9.400524          0.394895          18.192916
# ...

# %% [markdown]
# ---
# ### Less active traders
# ---

# %%
# Less active traders
df_Less_active_traders = data[data['Identifier'].isin(c0_id)] 
df_Less_active_traders
# Out:
#         Identifier  Week Number Date Start   Date End source_of_wealth  \
# 87               2            6  2022/1/26   2022/2/1           Salary
# 88               2            7   2022/2/2   2022/2/8           Salary
# 89               2            8   2022/2/9  2022/2/15           Salary
# 90               2            9  2022/2/16  2022/2/22           Salary
# 91               2           10  2022/2/23   2022/3/1           Salary
# ...            ...          ...        ...        ...              ...
# 109866        2442           83  2023/7/19  2023/7/25          Savings
# 109867        2442           84  2023/7/26   2023/8/1          Savings
# 109868        2442           85   2023/8/2   2023/8/8          Savings
# 109869        2442           86   2023/8/9  2023/8/15          Savings
# 109870        2442           87  2023/8/16  2023/8/22          Savings
#
#        employment_status  buy_values_7days  buy_number_7days  \
# ...

# %%
df_Less_active_traders_Weekly = df_Less_active_traders.groupby('Week Number').mean()
df_Less_active_traders_Weekly = df_Less_active_traders_Weekly.drop("Identifier", axis=1)
df_Less_active_traders_Weekly = df_Less_active_traders_Weekly.reset_index()
df_Less_active_traders_Weekly
# Out:
# C:\Users\mrbri\AppData\Local\Temp\ipykernel_27616\1014976730.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_Less_active_traders_Weekly = df_Less_active_traders.groupby('Week Number').mean()
#     Week Number  buy_values_7days  buy_number_7days  buy_values_14days  \
# 0             6         14.582632          4.000000          14.582632
# 1             7          0.000000          0.000000          14.582632
# 2             8          0.000000          0.000000           0.000000
# 3             9          0.000000          0.000000           0.000000
# 4            10          9.320000          1.250000           9.320000
# ..          ...               ...               ...                ...
# 77           83          2.369326          0.118785          10.922696
# ...

# %% [markdown]
# ---
# ### Dormant traders
# ---

# %%
# Dormant traders
df_Dormant_traders = data[data['Identifier'].isin(c2_id)]
df_Dormant_traders
# Out:
#         Identifier  Week Number Date Start   Date End source_of_wealth  \
# 924             13           15  2022/3/30   2022/4/5          Savings
# 925             13           16   2022/4/6  2022/4/12          Savings
# 926             13           17  2022/4/13  2022/4/19          Savings
# 927             13           18  2022/4/20  2022/4/26          Savings
# 928             13           19  2022/4/27   2022/5/3          Savings
# ...            ...          ...        ...        ...              ...
# 111252        2601           86   2023/8/9  2023/8/15          Savings
# 111253        2601           87  2023/8/16  2023/8/22          Savings
# 111448        2648           85   2023/8/2   2023/8/8          Savings
# 111449        2648           86   2023/8/9  2023/8/15          Savings
# 111450        2648           87  2023/8/16  2023/8/22          Savings
#
#        employment_status  buy_values_7days  buy_number_7days  \
# ...

# %%
df_Dormant_traders_Weekly = df_Dormant_traders.groupby('Week Number').mean()
df_Dormant_traders_Weekly = df_Dormant_traders_Weekly.drop("Identifier", axis=1)
df_Dormant_traders_Weekly = df_Dormant_traders_Weekly.reset_index()
df_Dormant_traders_Weekly
# Out:
# C:\Users\mrbri\AppData\Local\Temp\ipykernel_27616\3417430800.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_Dormant_traders_Weekly = df_Dormant_traders.groupby('Week Number').mean()
#     Week Number  buy_values_7days  buy_number_7days  buy_values_14days  \
# 0            15         16.608823          1.588235          16.608823
# 1            16         12.431190          0.771429          20.498332
# 2            17         55.935235          1.186047          66.053645
# 3            18        558.727511          2.744681         609.902301
# 4            19       1629.060537          2.851852        2115.360408
# ..          ...               ...               ...                ...
# 68           83         63.508547          0.474138         127.390434
# ...

# %% [markdown]
# ---
# ### Exploration
# ---

# %% [markdown]
# df_High_value_traders_Weekly
# df_Stable_traders_Weekly
# df_Less_active_traders_Weekly
# df_Dormant_traders_Weekly

# %%
print(df_High_value_traders_Weekly.columns)
# Out:
# Index(['Week Number', 'buy_values_7days', 'buy_number_7days',
#        'buy_values_14days', 'buy_number_14days', 'sell_values_7days',
#        'sell_number_7days', 'sell_values_14days', 'sell_number_14days',
#        'net inflow 7days', 'net inflow 14days', 'Time since last trade',
#        'withdraw value 7days', 'withdraw times 7days', 'withdraw value 14days',
#        'withdraw times 14days', 'deposit value 7days', 'deposit times 7days',
#        'deposit value 14days', 'deposit times 14days', 'churn percentage',
#        'markert situation', 'Event(Withdraw) Count', 'Event(Stock) Count',
#        'Screen(Stock) Count', 'session length 7days', 'session length 14days',
#        'total events 7 days', 'total events 14days', 'buy value change',
#        'sell value change', 'buy number change', 'sell number change',
#        'deposit change', 'session time change', 'event_name', 'screen_name'],
#       dtype='object')

# %% [markdown]
# ---

# %%
# 'trading_volumes_7days'
buy = pd.merge(df_High_value_traders_Weekly[['Week Number', 'buy_number_7days']], df_Stable_traders_Weekly[['Week Number', 'buy_number_7days']],
                     on='Week Number', how='outer')

buy = pd.merge(buy, df_Less_active_traders_Weekly[['Week Number', 'buy_number_7days']],
                     on='Week Number', how='outer')


buy = pd.merge(buy, df_Dormant_traders_Weekly[['Week Number', 'buy_number_7days']],
                     on='Week Number', how='outer')

buy.columns = ['Week Number', 'High_value_traders', 'Stable_traders', 'Less_active_traders', 'Dormant_traders']
buy.fillna(0, inplace=True)
buy.sort_values(by='Week Number', ascending=True, inplace=True)

buy
# Out:
# C:\Users\mrbri\AppData\Local\Temp\ipykernel_27616\2398931408.py:9: FutureWarning: Passing 'suffixes' which cause duplicate columns {'buy_number_7days_x'} in the result is deprecated and will raise a MergeError in a future version.
#   buy = pd.merge(buy, df_Dormant_traders_Weekly[['Week Number', 'buy_number_7days']],
#     Week Number  High_value_traders  Stable_traders  Less_active_traders  \
# 73            1            0.000000        1.000000             0.000000
# 74            2            0.000000        1.000000             0.000000
# 75            3            0.000000        0.000000             0.000000
# 76            4            0.000000        0.000000             0.000000
# 77            5            0.000000        0.000000             0.000000
# ..          ...                 ...             ...                  ...
# 68           83            2.303311        0.394895             0.118785
# 69           84            2.365918        0.342144             0.190608
# ...

# %%
sell = pd.merge(df_High_value_traders_Weekly[['Week Number', 'sell_values_7days']], df_Stable_traders_Weekly[['Week Number', 'sell_values_7days']],
                     on='Week Number', how='outer')

sell = pd.merge(sell, df_Less_active_traders_Weekly[['Week Number', 'sell_values_7days']],
                     on='Week Number', how='outer')


sell = pd.merge(sell, df_Dormant_traders_Weekly[['Week Number', 'sell_values_7days']],
                     on='Week Number', how='outer')

sell.columns = ['Week Number', 'High_value_traders', 'Stable_traders', 'Less_active_traders', 'Dormant_traders']
sell.fillna(0, inplace=True)
sell.sort_values(by='Week Number', ascending=True, inplace=True)
sell
# Out:
# C:\Users\mrbri\AppData\Local\Temp\ipykernel_27616\740996381.py:8: FutureWarning: Passing 'suffixes' which cause duplicate columns {'sell_values_7days_x'} in the result is deprecated and will raise a MergeError in a future version.
#   sell = pd.merge(sell, df_Dormant_traders_Weekly[['Week Number', 'sell_values_7days']],
#     Week Number  High_value_traders  Stable_traders  Less_active_traders  \
# 73            1            0.000000        0.000000             0.000000
# 74            2            0.000000        5.000000             0.000000
# 75            3            0.000000        0.000000             0.000000
# 76            4            0.000000        0.000000             0.000000
# 77            5            0.000000        0.000000             0.000000
# ..          ...                 ...             ...                  ...
# 68           83         1647.077352        7.259959             2.385379
# ...

# %%
plt.figure(figsize=(10, 6))

for column in buy.columns[1:]:
    plt.plot(buy['Week Number'], buy[column] + sell[column], label=column)

plt.legend()

plt.xlim(15,87)
plt.title('trading_volumes_7days')
plt.xlabel('Week Number')
plt.ylabel('Value')

plt.show()

# %%
# 'buy_values_7days'

merged_df = pd.merge(df_High_value_traders_Weekly[['Week Number', 'buy_values_7days']], df_Stable_traders_Weekly[['Week Number', 'buy_values_7days']],
                     on='Week Number', how='outer')

merged_df = pd.merge(merged_df, df_Less_active_traders_Weekly[['Week Number', 'buy_values_7days']],
                     on='Week Number', how='outer')


merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'buy_values_7days']],
                     on='Week Number', how='outer')

merged_df.columns = ['Week Number', 'High_value_traders', 'Stable_traders', 'Less_active_traders', 'Dormant_traders']
merged_df.fillna(0, inplace=True)
merged_df.sort_values(by='Week Number', ascending=True, inplace=True)

merged_df
# Out:
# C:\Users\mrbri\AppData\Local\Temp\ipykernel_27616\2055301285.py:10: FutureWarning: Passing 'suffixes' which cause duplicate columns {'buy_values_7days_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'buy_values_7days']],
#     Week Number  High_value_traders  Stable_traders  Less_active_traders  \
# 73            1            0.000000       10.000000             0.000000
# 74            2            0.000000        9.880000             0.000000
# 75            3            0.000000        0.000000             0.000000
# 76            4            0.000000        0.000000             0.000000
# 77            5            0.000000        0.000000             0.000000
# ..          ...                 ...             ...                  ...
# 68           83         1685.811100        9.400524             2.369326
# ...

# %%
plt.figure(figsize=(10, 6))

for column in merged_df.columns[1:]:
    plt.plot(merged_df['Week Number'], merged_df[column], label=column)

plt.legend()

plt.xlim(15,87)
plt.title('buy_values_7days')
plt.xlabel('Week Number')
plt.ylabel('Value')

plt.show()

# %% [markdown]
# ---

# %%
# 'buy_number_7days'

merged_df = pd.merge(df_High_value_traders_Weekly[['Week Number', 'buy_number_7days']], df_Stable_traders_Weekly[['Week Number', 'buy_number_7days']],
                     on='Week Number', how='outer')

merged_df = pd.merge(merged_df, df_Less_active_traders_Weekly[['Week Number', 'buy_number_7days']],
                     on='Week Number', how='outer')


merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'buy_number_7days']],
                     on='Week Number', how='outer')

merged_df.columns = ['Week Number', 'High_value_traders', 'Stable_traders', 'Less_active_traders', 'Dormant_traders']
merged_df.fillna(0, inplace=True)
merged_df.sort_values(by='Week Number', ascending=True, inplace=True)

merged_df
# Out:
# C:\Users\mrbri\AppData\Local\Temp\ipykernel_27616\4181662669.py:10: FutureWarning: Passing 'suffixes' which cause duplicate columns {'buy_number_7days_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'buy_number_7days']],
#     Week Number  High_value_traders  Stable_traders  Less_active_traders  \
# 73            1            0.000000        1.000000             0.000000
# 74            2            0.000000        1.000000             0.000000
# 75            3            0.000000        0.000000             0.000000
# 76            4            0.000000        0.000000             0.000000
# 77            5            0.000000        0.000000             0.000000
# ..          ...                 ...             ...                  ...
# 68           83            2.303311        0.394895             0.118785
# ...

# %%
plt.figure(figsize=(10, 6))

for column in merged_df.columns[1:]:
    plt.plot(merged_df['Week Number'], merged_df[column], label=column)

plt.legend()

plt.xlim(15,87)
plt.title('buy_number_7days')
plt.xlabel('Week Number')
plt.ylabel('Value')

plt.show()

# %% [markdown]
# ---

# %%
# 'buy_values_14days'

merged_df = pd.merge(df_High_value_traders_Weekly[['Week Number', 'buy_values_14days']], df_Stable_traders_Weekly[['Week Number', 'buy_values_14days']],
                     on='Week Number', how='outer')

merged_df = pd.merge(merged_df, df_Less_active_traders_Weekly[['Week Number', 'buy_values_14days']],
                     on='Week Number', how='outer')


merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'buy_values_14days']],
                     on='Week Number', how='outer')

merged_df.columns = ['Week Number', 'High_value_traders', 'Stable_traders', 'Less_active_traders', 'Dormant_traders']
merged_df.fillna(0, inplace=True)
merged_df.sort_values(by='Week Number', ascending=True, inplace=True)

plt.figure(figsize=(10, 6))

for column in merged_df.columns[1:]:
    plt.plot(merged_df['Week Number'], merged_df[column], label=column)

plt.legend()

plt.xlim(15,87)
plt.title('buy_values_14days')
plt.xlabel('Week Number')
plt.ylabel('Value')

plt.show()
# Out:
# C:\Users\mrbri\AppData\Local\Temp\ipykernel_27616\2222025626.py:10: FutureWarning: Passing 'suffixes' which cause duplicate columns {'buy_values_14days_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'buy_values_14days']],

# %%
# 'buy_number_14days'

merged_df = pd.merge(df_High_value_traders_Weekly[['Week Number', 'buy_number_14days']], df_Stable_traders_Weekly[['Week Number', 'buy_number_14days']],
                     on='Week Number', how='outer')

merged_df = pd.merge(merged_df, df_Less_active_traders_Weekly[['Week Number', 'buy_number_14days']],
                     on='Week Number', how='outer')


merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'buy_number_14days']],
                     on='Week Number', how='outer')

merged_df.columns = ['Week Number', 'High_value_traders', 'Stable_traders', 'Less_active_traders', 'Dormant_traders']
merged_df.fillna(0, inplace=True)
merged_df.sort_values(by='Week Number', ascending=True, inplace=True)

plt.figure(figsize=(10, 6))

for column in merged_df.columns[1:]:
    plt.plot(merged_df['Week Number'], merged_df[column], label=column)

plt.legend()

plt.xlim(15,87)
plt.title('buy_number_14days')
plt.xlabel('Week Number')
plt.ylabel('Value')

plt.show()
# Out:
# C:\Users\mrbri\AppData\Local\Temp\ipykernel_27616\3148621434.py:10: FutureWarning: Passing 'suffixes' which cause duplicate columns {'buy_number_14days_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'buy_number_14days']],

# %%
# 'sell_values_7days'

merged_df = pd.merge(df_High_value_traders_Weekly[['Week Number', 'sell_values_7days']], df_Stable_traders_Weekly[['Week Number', 'sell_values_7days']],
                     on='Week Number', how='outer')

merged_df = pd.merge(merged_df, df_Less_active_traders_Weekly[['Week Number', 'sell_values_7days']],
                     on='Week Number', how='outer')


merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'sell_values_7days']],
                     on='Week Number', how='outer')

merged_df.columns = ['Week Number', 'High_value_traders', 'Stable_traders', 'Less_active_traders', 'Dormant_traders']
merged_df.fillna(0, inplace=True)
merged_df.sort_values(by='Week Number', ascending=True, inplace=True)

plt.figure(figsize=(10, 6))

for column in merged_df.columns[1:]:
    plt.plot(merged_df['Week Number'], merged_df[column], label=column)

plt.legend()

plt.xlim(15,87)
plt.title('sell_values_7days')
plt.xlabel('Week Number')
plt.ylabel('Value')

plt.show()
# Out:
# C:\Users\mrbri\AppData\Local\Temp\ipykernel_27616\295723333.py:10: FutureWarning: Passing 'suffixes' which cause duplicate columns {'sell_values_7days_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'sell_values_7days']],

# %%
'sell_number_7days'

merged_df = pd.merge(df_High_value_traders_Weekly[['Week Number', 'sell_number_7days']], df_Stable_traders_Weekly[['Week Number', 'sell_number_7days']],
                     on='Week Number', how='outer')

merged_df = pd.merge(merged_df, df_Less_active_traders_Weekly[['Week Number', 'sell_number_7days']],
                     on='Week Number', how='outer')


merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'sell_number_7days']],
                     on='Week Number', how='outer')

merged_df.columns = ['Week Number', 'High_value_traders', 'Stable_traders', 'Less_active_traders', 'Dormant_traders']
merged_df.fillna(0, inplace=True)
merged_df.sort_values(by='Week Number', ascending=True, inplace=True)

plt.figure(figsize=(10, 6))

for column in merged_df.columns[1:]:
    plt.plot(merged_df['Week Number'], merged_df[column], label=column)

plt.legend()

plt.xlim(15,87)
plt.title('sell_number_7days')
plt.xlabel('Week Number')
plt.ylabel('Value')

plt.show()
# Out:
# C:\Users\mrbri\AppData\Local\Temp\ipykernel_27616\2890934489.py:10: FutureWarning: Passing 'suffixes' which cause duplicate columns {'sell_number_7days_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'sell_number_7days']],

# %%
'sell_values_14days'

merged_df = pd.merge(df_High_value_traders_Weekly[['Week Number', 'sell_values_14days']], df_Stable_traders_Weekly[['Week Number', 'sell_values_14days']],
                     on='Week Number', how='outer')

merged_df = pd.merge(merged_df, df_Less_active_traders_Weekly[['Week Number', 'sell_values_14days']],
                     on='Week Number', how='outer')


merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'sell_values_14days']],
                     on='Week Number', how='outer')

merged_df.columns = ['Week Number', 'High_value_traders', 'Stable_traders', 'Less_active_traders', 'Dormant_traders']
merged_df.fillna(0, inplace=True)
merged_df.sort_values(by='Week Number', ascending=True, inplace=True)

plt.figure(figsize=(10, 6))

for column in merged_df.columns[1:]:
    plt.plot(merged_df['Week Number'], merged_df[column], label=column)

plt.legend()

plt.xlim(15,87)
plt.title('sell_values_14days')
plt.xlabel('Week Number')
plt.ylabel('Value')

plt.show()
# Out:
# C:\Users\mrbri\AppData\Local\Temp\ipykernel_27616\465236905.py:10: FutureWarning: Passing 'suffixes' which cause duplicate columns {'sell_values_14days_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'sell_values_14days']],

# %%
'sell_number_14days'

merged_df = pd.merge(df_High_value_traders_Weekly[['Week Number', 'sell_number_14days']], df_Stable_traders_Weekly[['Week Number', 'sell_number_14days']],
                     on='Week Number', how='outer')

merged_df = pd.merge(merged_df, df_Less_active_traders_Weekly[['Week Number', 'sell_number_14days']],
                     on='Week Number', how='outer')


merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'sell_number_14days']],
                     on='Week Number', how='outer')

merged_df.columns = ['Week Number', 'High_value_traders', 'Stable_traders', 'Less_active_traders', 'Dormant_traders']
merged_df.fillna(0, inplace=True)
merged_df.sort_values(by='Week Number', ascending=True, inplace=True)

plt.figure(figsize=(10, 6))

for column in merged_df.columns[1:]:
    plt.plot(merged_df['Week Number'], merged_df[column], label=column)

plt.legend()

plt.xlim(15,87)
plt.title('sell_number_14days')
plt.xlabel('Week Number')
plt.ylabel('Value')

plt.show()
# Out:
# C:\Users\mrbri\AppData\Local\Temp\ipykernel_27616\376441649.py:10: FutureWarning: Passing 'suffixes' which cause duplicate columns {'sell_number_14days_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'sell_number_14days']],

# %%
'session length 7days'

merged_df = pd.merge(df_High_value_traders_Weekly[['Week Number', 'session length 7days']], df_Stable_traders_Weekly[['Week Number', 'session length 7days']],
                     on='Week Number', how='outer')

merged_df = pd.merge(merged_df, df_Less_active_traders_Weekly[['Week Number', 'session length 7days']],
                     on='Week Number', how='outer')


merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'session length 7days']],
                     on='Week Number', how='outer')

merged_df.columns = ['Week Number', 'High_value_traders', 'Stable_traders', 'Less_active_traders', 'Dormant_traders']
merged_df.fillna(0, inplace=True)
merged_df.sort_values(by='Week Number', ascending=True, inplace=True)

plt.figure(figsize=(10, 6))

for column in merged_df.columns[1:]:
    plt.plot(merged_df['Week Number'], merged_df[column], label=column)

plt.legend()

plt.xlim(15,87)
plt.title('session length 7days')
plt.xlabel('Week Number')
plt.ylabel('Value')

plt.show()
# Out:
# C:\Users\mrbri\AppData\Local\Temp\ipykernel_27616\4023876732.py:10: FutureWarning: Passing 'suffixes' which cause duplicate columns {'session length 7days_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'session length 7days']],

# %%
'session length 14days'

merged_df = pd.merge(df_High_value_traders_Weekly[['Week Number', 'session length 14days']], df_Stable_traders_Weekly[['Week Number', 'session length 14days']],
                     on='Week Number', how='outer')

merged_df = pd.merge(merged_df, df_Less_active_traders_Weekly[['Week Number', 'session length 14days']],
                     on='Week Number', how='outer')


merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'session length 14days']],
                     on='Week Number', how='outer')

merged_df.columns = ['Week Number', 'High_value_traders', 'Stable_traders', 'Less_active_traders', 'Dormant_traders']
merged_df.fillna(0, inplace=True)
merged_df.sort_values(by='Week Number', ascending=True, inplace=True)

plt.figure(figsize=(10, 6))

for column in merged_df.columns[1:]:
    plt.plot(merged_df['Week Number'], merged_df[column], label=column)

plt.legend()

plt.xlim(15,87)
plt.title('session length 14days')
plt.xlabel('Week Number')
plt.ylabel('Value')

plt.show()
# Out:
# C:\Users\mrbri\AppData\Local\Temp\ipykernel_27616\2414310166.py:10: FutureWarning: Passing 'suffixes' which cause duplicate columns {'session length 14days_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'session length 14days']],

# %%
'total events 7 days'

merged_df = pd.merge(df_High_value_traders_Weekly[['Week Number', 'total events 7 days']], df_Stable_traders_Weekly[['Week Number', 'total events 7 days']],
                     on='Week Number', how='outer')

merged_df = pd.merge(merged_df, df_Less_active_traders_Weekly[['Week Number', 'total events 7 days']],
                     on='Week Number', how='outer')


merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'total events 7 days']],
                     on='Week Number', how='outer')

merged_df.columns = ['Week Number', 'High_value_traders', 'Stable_traders', 'Less_active_traders', 'Dormant_traders']
merged_df.fillna(0, inplace=True)
merged_df.sort_values(by='Week Number', ascending=True, inplace=True)

plt.figure(figsize=(10, 6))

for column in merged_df.columns[1:]:
    plt.plot(merged_df['Week Number'], merged_df[column], label=column)

plt.legend()

plt.xlim(15,87)
plt.title('total events 7 days')
plt.xlabel('Week Number')
plt.ylabel('Value')

plt.show()
# Out:
# C:\Users\mrbri\AppData\Local\Temp\ipykernel_27616\1592562365.py:10: FutureWarning: Passing 'suffixes' which cause duplicate columns {'total events 7 days_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'total events 7 days']],

# %%
'total events 14days'

merged_df = pd.merge(df_High_value_traders_Weekly[['Week Number', 'total events 14days']], df_Stable_traders_Weekly[['Week Number', 'total events 14days']],
                     on='Week Number', how='outer')

merged_df = pd.merge(merged_df, df_Less_active_traders_Weekly[['Week Number', 'total events 14days']],
                     on='Week Number', how='outer')


merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'total events 14days']],
                     on='Week Number', how='outer')

merged_df.columns = ['Week Number', 'High_value_traders', 'Stable_traders', 'Less_active_traders', 'Dormant_traders']
merged_df.fillna(0, inplace=True)
merged_df.sort_values(by='Week Number', ascending=True, inplace=True)

plt.figure(figsize=(10, 6))


for column in merged_df.columns[1:]:
    plt.plot(merged_df['Week Number'], merged_df[column], label=column)

plt.legend()

plt.xlim(15,87)
plt.title('total events 14days')
plt.xlabel('Week Number')
plt.ylabel('Value')

# 显示图形
plt.show()
# Out:
# C:\Users\mrbri\AppData\Local\Temp\ipykernel_27616\2621441213.py:10: FutureWarning: Passing 'suffixes' which cause duplicate columns {'total events 14days_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'total events 14days']],

# %%
'churn percentage'

merged_df = pd.merge(df_High_value_traders_Weekly[['Week Number', 'churn percentage']], df_Stable_traders_Weekly[['Week Number', 'churn percentage']],
                     on='Week Number', how='outer')

merged_df = pd.merge(merged_df, df_Less_active_traders_Weekly[['Week Number', 'churn percentage']],
                     on='Week Number', how='outer')


merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'churn percentage']],
                     on='Week Number', how='outer')

merged_df.columns = ['Week Number', 'High_value_traders', 'Stable_traders', 'Less_active_traders', 'Dormant_traders']
merged_df.fillna(0, inplace=True)
merged_df.sort_values(by='Week Number', ascending=True, inplace=True)

plt.figure(figsize=(10, 6))

for column in merged_df.columns[1:]:
    plt.plot(merged_df['Week Number'], merged_df[column], label=column)

plt.legend()

plt.xlim(15,87)
plt.title('churn percentage')
plt.xlabel('Week Number')
plt.ylabel('Value')

plt.show()
# Out:
# C:\Users\mrbri\AppData\Local\Temp\ipykernel_27616\1290085306.py:10: FutureWarning: Passing 'suffixes' which cause duplicate columns {'churn percentage_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_df = pd.merge(merged_df, df_Dormant_traders_Weekly[['Week Number', 'churn percentage']],

# %% [markdown]
# ---
# ---

# %% [markdown]
# df_High_value_traders_Weekly   df_Stable_traders_Weekly   df_Less_active_traders_Weekly  df_Dormant_traders_Weekly
#
# 'buy_values_7days' - 'buy_number_7days'
#
# 'buy_values_7days' - 'sell_values_7days'
#
# 'buy_values_7days' - 'sell_number_7days'
#
# 'sell_values_7days' - 'sell_number_7days'
#
# 'buy_values_7days' - 'session length 7days'
#
# 'buy_values_7days' - 'total events 7 days'
#
# 'sell_values_7days' - 'session length 7days'
#
# 'sell_values_7days' - 'total events 7 days'

# %%
# 'buy_values_7days' - 'buy_number_7days'

df1 = df_High_value_traders_Weekly[['buy_values_7days','buy_number_7days']]
df2 = df_Stable_traders_Weekly[['buy_values_7days','buy_number_7days']]
df3 = df_Less_active_traders_Weekly[['buy_values_7days','buy_number_7days']]
df4 = df_Dormant_traders_Weekly[['buy_values_7days','buy_number_7days']]

fig, ax = plt.subplots()

ax.scatter(df1['buy_values_7days'], df1['buy_number_7days'], color='blue', alpha = 0.5, s=25, label='High_value_traders')
ax.scatter(df2['buy_values_7days'], df2['buy_number_7days'], color='orange', alpha = 0.5, s=25, label='Stable_traders')
ax.scatter(df3['buy_values_7days'], df3['buy_number_7days'], color='green', alpha = 0.5, s=25, label='Less_active_traders')
ax.scatter(df4['buy_values_7days'], df4['buy_number_7days'], color='red', alpha = 0.5, s=25, label='Dormant_traders')

# 添加图例
ax.legend()

# 添加轴标签和标题
ax.set_xlabel('buy_values_7days')
ax.set_ylabel('buy_number_7days')
ax.set_title('buy_values_7days vs buy_number_7days')

# 显示图形
plt.show()

# %%
# 'buy_values_7days' - 'sell_values_7days'

df1 = df_High_value_traders_Weekly[['buy_values_7days','sell_values_7days']]
df2 = df_Stable_traders_Weekly[['buy_values_7days','sell_values_7days']]
df3 = df_Less_active_traders_Weekly[['buy_values_7days','sell_values_7days']]
df4 = df_Dormant_traders_Weekly[['buy_values_7days','sell_values_7days']]

fig, ax = plt.subplots()

ax.scatter(df1['buy_values_7days'], df1['sell_values_7days'], color='blue', alpha = 0.5, s=25, label='High_value_traders')
ax.scatter(df2['buy_values_7days'], df2['sell_values_7days'], color='orange', alpha = 0.5, s=25, label='Stable_traders')
ax.scatter(df3['buy_values_7days'], df3['sell_values_7days'], color='green', alpha = 0.5, s=25, label='Less_active_traders')
ax.scatter(df4['buy_values_7days'], df4['sell_values_7days'], color='red', alpha = 0.5, s=25, label='Dormant_traders')

# 添加图例
ax.legend()

# 添加轴标签和标题
ax.set_xlabel('buy_values_7days')
ax.set_ylabel('sell_values_7days')
ax.set_title('buy_values_7days vs sell_values_7days')

# 显示图形
plt.show()

# %%
# 'buy_values_7days' - 'total events 7 days'

df1 = df_High_value_traders_Weekly[['total events 7 days','buy_values_7days']]
df2 = df_Stable_traders_Weekly[['total events 7 days','buy_values_7days']]
df3 = df_Less_active_traders_Weekly[['total events 7 days','buy_values_7days']]
df4 = df_Dormant_traders_Weekly[['total events 7 days','buy_values_7days']]

fig, ax = plt.subplots()

ax.scatter(df1['total events 7 days'], df1['buy_values_7days'], color='blue', alpha = 0.5, s=25, label='High_value_traders')
ax.scatter(df2['total events 7 days'], df2['buy_values_7days'], color='orange', alpha = 0.5, s=25, label='Stable_traders')
ax.scatter(df3['total events 7 days'], df3['buy_values_7days'], color='green', alpha = 0.5, s=25, label='Less_active_traders')
ax.scatter(df4['total events 7 days'], df4['buy_values_7days'], color='red', alpha = 0.5, s=25, label='Dormant_traders')

# 添加图例
ax.legend()

# 添加轴标签和标题
ax.set_xlabel('total events 7 days')
ax.set_ylabel('buy_values_7days')
ax.set_title('total events 7 days vs buy_values_7days')

# 显示图形
plt.show()

# %%
# 'sell_values_7days' - 'total events 7 days'

df1 = df_High_value_traders_Weekly[['total events 7 days','sell_values_7days']]
df2 = df_Stable_traders_Weekly[['total events 7 days','sell_values_7days']]
df3 = df_Less_active_traders_Weekly[['total events 7 days','sell_values_7days']]
df4 = df_Dormant_traders_Weekly[['total events 7 days','sell_values_7days']]

fig, ax = plt.subplots()

ax.scatter(df1['total events 7 days'], df1['sell_values_7days'], color='blue', alpha = 0.5, s=25, label='High_value_traders')
ax.scatter(df2['total events 7 days'], df2['sell_values_7days'], color='orange', alpha = 0.5, s=25, label='Stable_traders')
ax.scatter(df3['total events 7 days'], df3['sell_values_7days'], color='green', alpha = 0.5, s=25, label='Less_active_traders')
ax.scatter(df4['total events 7 days'], df4['sell_values_7days'], color='red', alpha = 0.5, s=25, label='Dormant_traders')

# 添加图例
ax.legend()

# 添加轴标签和标题
ax.set_xlabel('total events 7 days')
ax.set_ylabel('sell_values_7days')
ax.set_title('total events 7 days vs sell_values_7days')

# 显示图形
plt.show()

# %%
# 'buy_values_7days' - 'session length 7days'
df1 = df_High_value_traders_Weekly[['session length 7days','buy_values_7days']]
df2 = df_Stable_traders_Weekly[['session length 7days','buy_values_7days']]
df3 = df_Less_active_traders_Weekly[['session length 7days','buy_values_7days']]
df4 = df_Dormant_traders_Weekly[['session length 7days','buy_values_7days']]

fig, ax = plt.subplots()

ax.scatter(df1['session length 7days'], df1['buy_values_7days'], color='blue', alpha = 0.5, s=25, label='High_value_traders')
ax.scatter(df2['session length 7days'], df2['buy_values_7days'], color='orange', alpha = 0.5, s=25, label='Stable_traders')
ax.scatter(df3['session length 7days'], df3['buy_values_7days'], color='green', alpha = 0.5, s=25, label='Less_active_traders')
ax.scatter(df4['session length 7days'], df4['buy_values_7days'], color='red', alpha = 0.5, s=25, label='Dormant_traders')

# 添加图例
ax.legend()

# 添加轴标签和标题
ax.set_xlabel('session length 7days')
ax.set_ylabel('buy_values_7days')
ax.set_title('session length 7days vs buy_values_7days')

# 显示图形
plt.show()

# %%
# 'sell_values_7days' - 'session length 7days'

df1 = df_High_value_traders_Weekly[['session length 7days','sell_values_7days']]
df2 = df_Stable_traders_Weekly[['session length 7days','sell_values_7days']]
df3 = df_Less_active_traders_Weekly[['session length 7days','sell_values_7days']]
df4 = df_Dormant_traders_Weekly[['session length 7days','sell_values_7days']]

fig, ax = plt.subplots()

ax.scatter(df1['session length 7days'], df1['sell_values_7days'], color='blue', alpha = 0.5, s=25, label='High_value_traders')
ax.scatter(df2['session length 7days'], df2['sell_values_7days'], color='orange', alpha = 0.5, s=25, label='Stable_traders')
ax.scatter(df3['session length 7days'], df3['sell_values_7days'], color='green', alpha = 0.5, s=25, label='Less_active_traders')
ax.scatter(df4['session length 7days'], df4['sell_values_7days'], color='red', alpha = 0.5, s=25, label='Dormant_traders')

# 添加图例
ax.legend()

# 添加轴标签和标题
ax.set_xlabel('session length 7days')
ax.set_ylabel('sell_values_7days')
ax.set_title('session length 7days vs sell_values_7days')

# 显示图形
plt.show()

# %%
# 'buy_values_7days' - 'churn percentage'

df1 = df_High_value_traders_Weekly[['churn percentage','buy_values_7days']]
df2 = df_Stable_traders_Weekly[['churn percentage','buy_values_7days']]
df3 = df_Less_active_traders_Weekly[['churn percentage','buy_values_7days']]
df4 = df_Dormant_traders_Weekly[['churn percentage','buy_values_7days']]

fig, ax = plt.subplots()

ax.scatter(df1['churn percentage'], df1['buy_values_7days'], color='blue', alpha = 0.5, s=25, label='High_value_traders')
ax.scatter(df2['churn percentage'], df2['buy_values_7days'], color='orange', alpha = 0.5, s=25, label='Stable_traders')
ax.scatter(df3['churn percentage'], df3['buy_values_7days'], color='green', alpha = 0.5, s=25, label='Less_active_traders')
ax.scatter(df4['churn percentage'], df4['buy_values_7days'], color='red', alpha = 0.5, s=25, label='Dormant_traders')

# 添加图例
ax.legend()

# 添加轴标签和标题
ax.set_xlabel('churn percentage')
ax.set_ylabel('buy_values_7days')
ax.set_title('churn percentage vs buy_values_7days')

# 显示图形
plt.show()

# %%
# 'sell_values_7days' - 'churn percentage'

df1 = df_High_value_traders_Weekly[['churn percentage','sell_values_7days']]
df2 = df_Stable_traders_Weekly[['churn percentage','sell_values_7days']]
df3 = df_Less_active_traders_Weekly[['churn percentage','sell_values_7days']]
df4 = df_Dormant_traders_Weekly[['churn percentage','sell_values_7days']]

fig, ax = plt.subplots()

ax.scatter(df1['churn percentage'], df1['sell_values_7days'], color='blue', alpha = 0.5, s=25, label='High_value_traders')
ax.scatter(df2['churn percentage'], df2['sell_values_7days'], color='orange', alpha = 0.5, s=25, label='Stable_traders')
ax.scatter(df3['churn percentage'], df3['sell_values_7days'], color='green', alpha = 0.5, s=25, label='Less_active_traders')
ax.scatter(df4['churn percentage'], df4['sell_values_7days'], color='red', alpha = 0.5, s=25, label='Dormant_traders')

# 添加图例
ax.legend()

# 添加轴标签和标题
ax.set_xlabel('churn percentage')
ax.set_ylabel('sell_values_7days')
ax.set_title('churn percentage vs sell_values_7days')

# 显示图形
plt.show()

# %%
# 'total events 7 days' - 'churn percentage'

df1 = df_High_value_traders_Weekly[['churn percentage','total events 7 days']]
df2 = df_Stable_traders_Weekly[['churn percentage','total events 7 days']]
df3 = df_Less_active_traders_Weekly[['churn percentage','total events 7 days']]
df4 = df_Dormant_traders_Weekly[['churn percentage','total events 7 days']]

fig, ax = plt.subplots()

ax.scatter(df1['churn percentage'], df1['total events 7 days'], color='blue', alpha = 0.5, s=25, label='High_value_traders')
ax.scatter(df2['churn percentage'], df2['total events 7 days'], color='orange', alpha = 0.5, s=25, label='Stable_traders')
ax.scatter(df3['churn percentage'], df3['total events 7 days'], color='green', alpha = 0.5, s=25, label='Less_active_traders')
ax.scatter(df4['churn percentage'], df4['total events 7 days'], color='red', alpha = 0.5, s=25, label='Dormant_traders')

# 添加图例
ax.legend()

# 添加轴标签和标题
ax.set_xlabel('churn percentage')
ax.set_ylabel('total events 7 days')
ax.set_title('churn percentage vs total events 7 days')

# 显示图形
plt.show()

# %%
# 'session length 7days' - 'churn percentage'

df1 = df_High_value_traders_Weekly[['churn percentage','session length 7days']]
df2 = df_Stable_traders_Weekly[['churn percentage','session length 7days']]
df3 = df_Less_active_traders_Weekly[['churn percentage','session length 7days']]
df4 = df_Dormant_traders_Weekly[['churn percentage','session length 7days']]

fig, ax = plt.subplots()

ax.scatter(df1['churn percentage'], df1['session length 7days'], color='blue', alpha = 0.5, s=25, label='High_value_traders')
ax.scatter(df2['churn percentage'], df2['session length 7days'], color='orange', alpha = 0.5, s=25, label='Stable_traders')
ax.scatter(df3['churn percentage'], df3['session length 7days'], color='green', alpha = 0.5, s=25, label='Less_active_traders')
ax.scatter(df4['churn percentage'], df4['session length 7days'], color='red', alpha = 0.5, s=25, label='Dormant_traders')

# 添加图例
ax.legend()

# 添加轴标签和标题
ax.set_xlabel('churn percentage')
ax.set_ylabel('session length 7days')
ax.set_title('churn percentage vs session length 7days')

# 显示图形
plt.show()
